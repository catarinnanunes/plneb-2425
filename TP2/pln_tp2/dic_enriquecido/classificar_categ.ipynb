# %%
import json
from collections import defaultdict
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Modelo BioBERTpt
MODEL_NAME = "neuralmind/bert-base-portuguese-cased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)

def get_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=32)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state[0, 0, :].numpy()

# Tradução das categorias do catalão
categorias_traduzidas = {
    'PRINCIPIS ACTIUS': 'Princípios activos',
    'ETIOPATOGÈNIA': 'Etiopatogénese',
    'TRACTAMENT': 'Tratamento',
    'CLÍNICA': 'Clínica',
    'EPIDEMIOLOGIA': 'Epidemiologia',
    'PREVENCIÓ': 'Prevenção',
    'ENTORN SOCIAL': 'Contexto social',
    'CONCEPTES GENERALS': 'Conceitos gerais',
    'DIAGNÒSTIC': 'Diagnóstico',
}

EXEMPLOS_CATEGORIAS = {
    "Governança e administração pública": [
        "Accountability", "Acesso à informação", "Agenda estratégica", "Agenda política",
        "Alocação de recursos", "Colegiado", "Compliance", "Controle", "Controle social",
        "Pacto", "Pactuação", "Política"
    ],
    "Políticas e intervenções na saúde pública": [
        "Ações de saúde", "Análise de situação em saúde", "Avaliação em saúde",
        "Planejamento em saúde", "Política pública de saúde", "Sala de situação de saúde",
        "Serviços de saúde", "Valor público em saúde"
    ],
    "Monitoramento e avaliação": [
        "Acompanhamento", "Análise de indicadores", "Auditoria", "Avaliação de impacto",
        "Avaliação de processo", "Avaliação de resultados", "Indicador", "Linha de base"
    ],
    "Gestão de dados e informação": [
        "Agregação de dados", "Análise de dados", "Banco de dados", "Base de dados",
        "Big data", "Ciência da informação", "Coleta de dados", "Confiabilidade",
        "Metadados", "Qualidade da informação", "Segurança da informação"
    ],
    "Planeamento e estratégia": [
        "Análise de viabilidade", "Análise estratégica", "Análise ex-ante", "Cadeia de valor",
        "Ciclo de políticas públicas", "Objetivo", "Cenário", "Orçamento", "Plano",
        "Referencial estratégico"
    ],
    "Metodologias e ferramentas": [
        "Benchmarking", "Brainstorming", "Cálculo do indicador", "Machine learning",
        "Mensuração", "Método", "Metodologia", "Parâmetro", "Unidade de medida"
    ],

    "Componentes e conceitos farmacológicos": [
        "Analgésico", "Antibiótico", "Antiviral", "Antisséptico", "Anti-inflamatório",
        "Anticoagulante", "Antihistamínico", "Corticosteróide", "Diurético", "Sedativo"
    ],

    "Princípios activos": [
        "Acalabrutinib", "Anakinra", "Azitromicina", "Baricitinib", "Bevacizumab",
        "Dexametasona", "Hidroxicloroquina", "Remdesivir", "Ritonavir", "Tocilizumab"
    ],

    "Etiopatogénese": [
        "Apicoplasto", "Apoptose", "Bioadesão", "Bainha de mielina",
        "Perlecan", "DNA", "ARN", "ARN missatger",
        "(herpes) zóster", "Araraquara", "MERS-CoV", "Avium",
        "Vírus Cantagalo", "Vírus amarílico", "Vírus respiratório sincicial",
        "Rato de rabo peludo", "Genes do imprinting"
    ],

    "Tratamento": [
        "Artrodistrator", "Bipsoro eletrônico", "Bisturi óptico",
        "Pinça óptica", "Trocáter", "Videodermatoscópio",
        "Radiocirurgia", "Pleurodese", "Terapia gênica", "Cirurgia a céu aberto", "Enxerto orgânico"
    ],

    "Clínica": [
        "Adenoma", "Acne", "Abcesso", "Acidose metilmalônica",
        "Alergia asmática", "Angina instável",
        "Atrofia espinhal progressiva tardia", "Barriga de cerveja",
        "Câncer de boca", "Bulimia nervosa", "Câncer de mama",
        "Poliparasitismo", "Transtorno do pânico",
        "Síndrome hemolítica urêmica", "Tumor de Walke", "Esgotamento mental"
    ],

    "Conceitos gerais": [
        "(d)escamação", "Gram-negativo", "Gram-positivo",
        "Epilepsia menor", "Abdominal", "Aberrante", "Absorção",
        "Adolescente", "Adrenérgico", "Aerossol", "Afinidade",
        "Agente", "Adstringente", "Acidez", "Adaptação",
        "Adenite", "Aditivo", "Adjuvante", "Adsorção", "Acumulação",
        "Anumérica", "Acomodação", "Acidental", "Acatisia", "Abstinência"
    ],

    "Diagnóstico": [
        "Análise biomecânica", "Baciloscopia", "Bio feedback", "Ceratoscopia",
        "Pleurodese", "Radiocirurgia", "Terapia gênica", "Videomicroscopia",
        "PCR", "Prova PCR"
    ],

    "Epidemiologia": [
        "MERS‑CoV", "Vírus respiratório sincicial", "(herpes) zóster",
        "Poliparasitismo", "Vírus Cantagalo", "Vírus amarílico"
    ],

    "Prevenção": [
        "EPI", "Máscara FFP", "Mascareta quirúrgica", "Pauta vacunal"
    ],

    "Anatomia": [
        "Sistema nervoso parassimpático", "Sistema nervoso periférico", "Terminal nervoso simpático", "Córtex cingulado",
        "Ilhota pancreática", "Cavidade pleural", "Líquido cefalorraquidiano", "Sistema endócrino", "Membrana celular",
        "Núcleo paraventricular", "Núcleo mediano da rafe", "Sistema límbico", "Veia porta"
    ]


}


# Calcular embeddings médios para cada categoria
categoria_embeddings = {
    cat: np.stack([get_embedding(e) for e in exemplos]).mean(axis=0)
    for cat, exemplos in EXEMPLOS_CATEGORIAS.items()
}

with open("dicionario_final_similares.json", encoding="utf-8") as f:
    termos = json.load(f)

resultado = defaultdict(dict)

for termo, dados in termos.items():
    if "Categoria" in dados:
        cat_catalan = dados["Categoria"]
        cat_pt = categorias_traduzidas.get(cat_catalan, cat_catalan)
    else:
        termo_emb = get_embedding(termo)
        sims = {cat: cosine_similarity([termo_emb], [emb])[0, 0]
                for cat, emb in categoria_embeddings.items()}
        cat_pt = max(sims, key=sims.get)
    resultado[cat_pt][termo] = {k: v for k, v in dados.items() if k != "Categoria"}

with open("dicionario_final_categorizado.json", "w", encoding="utf-8") as f:
    json.dump(resultado, f, ensure_ascii=False, indent=2)

print("Classificação concluída! Resultado dicionario_final_categorizado.json")
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\huggingface_hub\file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Classificação concluída! Resultado dicionario_final_categorizado.json

# %%
with open("dicionario_final_categorizado.json", encoding="utf-8") as f:
    dados = json.load(f)

for categoria, termos in dados.items():
    print(f"Categoria: {categoria}")
    print("Termos associados:", list(termos.keys()))
    print()
# Out:
# Categoria: Conceitos gerais
# Termos associados: ['ACA', 'Alta', 'ARN', 'ARNm', 'ARV', 'Ensaio clínico aleatorizado', 'Ensaio clínico em ocultaçao', 'Ensaio clínico em dupla ocultação', 'Ensaio clínico em tripla ocultação', 'Ensaio clínico controlado', 'Ensaio de intervenção comunitária', 'Careta', 'Càrrega vírica', 'Cas possible', 'Cèl·lula B', 'Cèl·lula T', 'Citocina', 'Contagi mediat', 'Convidecia', 'Covid', 'Covid-19', 'Covid persistent', 'Defesas', 'Desescalament', 'Distanàsia', 'Distància física', 'Distanciament físic', 'Èmesi', 'ERTO', 'Acontecimento adverso', 'Estudo clínico', 'Estudo de fase 0', 'Estudo farmacológico', 'Estudo exploratório', 'Estudo de confirmação', 'Estudo de vigilância pós-comercialização', 'Estudo pré-clínico', 'GCE', 'Goteta', 'Grup de convivència', 'Grup de convivència ampliada', 'Grup de convivència estable', 'IA 1', 'IA 2', 'IECA', 'Imune', 'Imunitário', 'Imunidade', 'Imunidade ativa', 'Imunidade adquirida', 'Immunitat adquirida', 'Immunitat col·lectiva', 'Immunitat congènita', 'Immunitat de comunitat', 'Immunitat específica', 'Imunidade específica intencional', 'Immunitat específica espontània', 'Immunitat específica intencionada', 'Imunidade específica espontânea', 'Immunitat específica no intencionada', 'Imunidade específica passiva', 'Immunitat inespecífica', 'Imunidade congénita', 'Imunização ativa', 'Immunització activa', 'Imunogénico', 'Imunogenicidade immunogeniciteit', 'Imunológico', 'LDH', 'Linfócito', 'Célula B', 'Célula de memória', 'Célula T', 'Macrófago', 'Mascareta', 'MRNA', 'Ofec', 'Onada', 'PCR', 'Període de latència', 'Pernió', 'Placebo', 'Policàrdia', 'Profilàctica', 'Proteïna espícula', 'QV', 'RAC', 'Ratapenada', 'Ratpenat', 'Rebrotada epidèmica', 'Recerca de contactes', 'Rentada de mans', 'Rentat de mans', 'RNA', 'SARS', 'SDRA', 'Serovar', 'Superpropagador -a', 'Taxa bruta de mortalitat', 'Tempestade de citocinas', 'Temps de Quick', 'Test immunològic', 'Test serològic', 'Treball a distància', 'UCI', 'Vacuna Moderna', 'Vacunació primària', 'VOI', 'Zorecimeran', 'Abeta', 'Alumã', 'Barriga d’água', 'Barriga de cerveja', 'Bengala instrumentalizada', 'Blockbuster', 'Caramboleira', 'Catuama', 'Dicroismo circular', 'Éfedra', 'Elisa indireto', 'Falsa arnica', 'Gomesina', 'Hipernasalidade', 'Jacalina', 'Lopap', 'Microtrans', 'Muleta instrumentalizada', 'Perlecan', 'Pluma grande', 'Potencial evocado', 'Raman', 'Razão de chances', 'Salgadão', 'Teleconsulta', 'Trocáter', 'Ubiquitina', 'Veia porta', 'ACTH', 'Gram-negativo', 'Gram-positivo', 'Abcesso', 'Abdominal', 'Aberrante', 'Aborto', 'Abrupto', 'Absorção', 'Abstinência', 'Acatisia', 'Acidental', 'Acidez', 'Acinesia', 'Acne', 'Acomodação', 'Activar', 'Actividade', 'Activo', 'Acuidade', 'Acumulação', 'Adaptação', 'Adenite', 'Adenoma', 'Adequado', 'Aderência', 'Adicional', 'Aditivo', 'Adjuvante', 'Adolescente', 'Adsorção', 'Adulto', 'Aeróbio', 'Afasia', 'Afinidade', 'Agente', 'Agitação', 'Agonista', 'Agravação', 'Agregação', 'Agressividade', 'Agudo', 'Alcalose', 'Alcilação', 'Alergia cruzada', 'Alerta', 'Alimentar', 'Alternar', 'Alternativo', 'Alucinação', 'Ambiente', 'Ambulante', 'Amina', 'Amnésia', 'Anabólico', 'Anal', 'Anamnésia', 'Anestésico', 'Anisocoria', 'Aniónico', 'Anormal', 'Antagonista', 'Antecedente', 'Anterógrado', 'Antiflogístico', 'Antitumor', 'Antitússico', 'Anúria', 'Apatia', 'Aplasia', 'Aproximado', 'Aquoso', 'Aromático', 'Articular', 'Artificial', 'Ascite', 'Aspiração', 'Assepsia', 'Assistir', 'Asséptico', 'Atonia', 'Atraso', 'Atrial', 'Atrofia', 'Atípico', 'Atópico', 'Auditivo', 'Aura', 'Aural', 'Auscultação', 'Ausência', 'Automatismo', 'Autónomo', 'Açúcar invertido', 'Barreira', 'Basal', 'Benigno', 'Biliar', 'Bloqueio', 'Calcemia', 'Calcificação', 'Calciúria', 'Camada superficial', 'Canal', 'Capacidade', 'Capacidade vital', 'Castração', 'Cateter', 'Caudal', 'Cavidade', 'Cerebelar', 'Cerúmen', 'Choque', 'Cicatrização', 'Circulação', 'Classificação', 'Claudicação', 'Clitórico', 'Cloaca', 'Clássico', 'Coito', 'Colangiografia', 'Colapso', 'Colerétic ...
#
# Categoria: Princípios activos
# Termos associados: ['Acalabrutinib', 'Ad5-nCoV', 'ADG20', 'Aïllat', 'Alunacedase alfa', 'Ambroxol', 'AMY-101', 'Anacinra', 'Antiálgico', 'Antiàlgic', 'Antibiótico', 'Antipirético', 'Antirretroviral ARV', 'Antitèrmic', 'Antivírico', 'Apilimod', 'Apremilast', 'ASC09F', 'Atibuclimab', 'ATYR1923', 'Aviptadil', 'Azitromicina', 'Bamlanivimab', 'Baricitinib', 'Bemcentinib', 'Bevacizumab', 'Boceprevir', 'Bombolla', 'Brensocatib', 'Brequinar', 'Brincidofovir', 'Bromexina', 'Broncodilatador', 'Budesonida', 'Camostat', 'Camrelizumab', 'Canacinumab', 'Casirivimab', 'CD24Fc', 'Cenicriviroc', 'Ciclesonida', 'Clazacizumab', 'Clofazimina', 'Cloroquina', 'Cobicistat', 'Colchicina', 'Comirnaty', 'Conestate alfa', 'CoronaVac', 'Danoprevir', 'Darunavir', 'Dazcapistat', 'Deshidrodidemnina B', 'Destret respiratori de l’adult', 'Destret respiratori del nadó', 'Dexametasona', 'Dosi de reforç', 'Eculizumab', 'Emapalumab', 'Emtricitabina', 'Emvododstat', 'Enoxaparina', 'Enpatoran', 'Ensovibep', 'Estadi d’incubació', 'Estudi d’ús terapèutic', 'Etesevimab', 'Favipiravir', 'Fenofibrato', 'Fingolimod', 'Galidesivir', 'Gimsilumab', 'Goflikicept', 'Gota de Flügge', 'Heparina', 'Hidroxicloroquina', 'Ibuprofeno ibuprofen', 'Icatibant', 'Imdevimab', 'Índex de letalitat', 'Inibidor da enzima conversora da angiotensina IECA', 'Interferão beta', 'Lanadelumab', 'Lenzilumab', 'Leronlimab', 'Lopinavir', 'MEDI 3506', 'Meplazumab', 'Metilprednisolona', 'Molnupiravir', 'Montelukast', 'Mupadolimab', 'Muriac', 'Nafamostat', 'Nombre reproductiu bàsic', 'OP-101', 'Opaganib', 'Oseltamivir', 'Otilimab', 'Passaport d’immunitat', 'Passaport immunològic', 'Pemziviptadil', 'Peplòmer', 'Pic de contagis', 'Picnocàrdia', 'Desidrodidemnina B', 'Pneumònia d’aspiració congènita', 'Població objectiu', 'Prednisolona', 'Punt d’inoculació', 'Raspallet', 'Ravulizumab', 'Recepció, acollida i classificació', 'Regdanvimab', 'Remdesivir', 'Revaccinació', 'Ribavirina', 'Ritonavir', 'Ruxolitinib', 'Sarilumab', 'Selinexor', 'Siltuximab', 'Rapamicina sirolimus', 'Sotrovimab', 'Spikevax', 'Subasumstat', 'Talidomida', 'Taquisistòlia', 'Tenofovir', 'Tixagevimab', 'Tocilizumab', 'Tractament amb oxigen', 'TRV027', 'Umifenovir', 'Vaccí', 'Vaccinació', 'Vacuna d’ARNm', 'Vacuna Johnson &amp; Johnson', 'Vafidemstat', 'Variant de preocupació', 'Variant vírica', 'Vaxzevria', 'Vidofludimus', 'Viricida', 'Voliac', 'Vorapaxar', 'Zilucoplan', 'Avium', 'Biomembrana', 'Brometo de piridostigmina', 'Coréia de sydenham', 'Crotoxina', 'Curativo de hidrogel', 'Esquistossomicida', 'Galantamina', 'Hidroxiapatita', 'Homocisteína', 'Insulina encapsulada', 'Isoflavona aglicona', 'Kava-kava', 'Leptina', 'Memantina', 'Óxido nítrico', 'Retinol binding protein', 'Sal de escopolamina', 'Shitake', 'Tripanossomicida', 'Acidose', 'Aerofagia', 'Alcalina', 'Aminoácido', 'Ampola', 'Anidro', 'Antianginoso', 'Antraz', 'Anxiolítico', 'Balanite', 'Betablocante', 'Bradicardia', 'Ceratite', 'Cerebrospinal', 'Co-enzima', 'Colagénio', 'Colangite', 'Colírio', 'Convulsão', 'Derivado', 'Destilar', 'Empiema', 'Emulsão', 'Enantema', 'Enfisema', 'Espermicida', 'Estase', 'Estrabismo', 'Extracto', 'Fibrina', 'Fontanela', 'Fungicida', 'Germicida', 'Gonádico', 'Hidroxilação', 'Hidrófobo', 'Iatorgénico', 'Lacrimal', 'Lipofílico', 'Lípido', 'Melanona', 'Mononucleose', 'Nistagmo', 'Nulípara', 'Paracentese', 'Paradoxal', 'Parotidite', 'Penicilinase', 'Pericardite', 'Prostaglandina(s)', 'Protéase', 'Prurítico', 'Salúrico', 'Telangiectasia', 'Torcicolo', 'Toxina', 'Tétano', 'Coronabonds', 'Cecv', 'Coxartrose', 'Ctg', 'Hem', 'Hipotálamo', 'Litíase', 'Otólito', 'Pólipo', 'Rentev', 'Sns', 'Tmrg', 'Ucin']
#
# Categoria: Etiopatogénese
# Termos associados: ['Ácido desoxirribonucleico', 'Ácido ribonucleico', 'ADN', 'Aerossol', 'Agente biológico', 'Isolado de vírus', 'Anticorpo', 'Antigénio', 'ARN missatger', 'Bastonet', 'Cadena de transmissió', 'Cápside', 'Gato-de-algália', 'Contagi immediat', 'Corba de contagis', 'Coronavírus', 'Coronavírus responsável pela COVID-19', 'Coronavírus MERS-CoV coronavírus responsável pela MERS', 'Coronavírus responsável pela SARS', 'DNA', 'Envelope viral', 'Esgotament', 'Peplómero', 'Excés de morts', 'Exsudat nasofaringi', 'Fagocitose', 'Fluid bucofaringi', 'Fluid nasofaringi', 'Gat d’algàlia', 'Gel desinfectant', 'Genoma', 'Gotícula respiratória', 'Hostatger', 'Espécie hospedeira', 'Hospedeiro intermédio', 'Immunitat natural', 'Índex de mortalitat', 'Inflamação', 'Interferão', 'IT', 'LET', 'Malaltia del coronavirus 2019', 'MERS', 'MERS-CoV', 'Muricec', 'Mutação', 'Pacient zero', 'Pangolim', 'Parasita', 'Patogénico', 'Patogenicidade', 'Període latent', 'Perniosi', 'Proteína estrutural', 'Proteína spike', 'Prova de mostres agrupades', 'Pulmó de xoc', 'Morcego', 'Morcego-de-ferradura-pequeno', 'Reservatório', 'Resposta imunitária', 'Retrovírus', 'ARN mensageiro', 'Salto entre espécies', 'SARS-CoV', 'SARS-CoV-2', 'Serotipagem', 'Serotipus', 'Cepa', 'Sputnik V', 'SRAG', 'Tapament', 'Test d’antígens', 'Test per agrupament de mostres', 'Transmissão', 'Trombus', 'UVI', 'Vacuna d’ARN missatger', 'Vacuna d’mRNA', 'Vacuna de Wuhan', 'Vacuna Gamaleya', 'Vacuna NovaVax', 'Vacuna Oxford-AstraZeneca', 'Vacuna Pfizer/BioNTech', 'Vacuna profilàctica', 'Variante', 'Variante de interesse', 'Variante de preocupação', 'Partícula viral', 'Virulência', 'Vírus', 'VOC', 'Zoonose', 'Zoonótico', 'Adjuvante genético', 'Antimonial pentavalente', 'Apicoplasto', 'Araraquara', 'Astemizol', 'Bacilo de koch', 'Bainha de mielina', 'Bioadesão', 'Biomarcador', 'Cogumelo-do-sol', 'Elisa in house', 'Equinácea', 'Erva-de-são-joão', 'Gene dinámico', 'Gene expresso', 'Genes do imprinting', 'Interferon gama', 'Jogador patológico', 'Mal da vaca louca', 'Mamica de cadela', 'Mão de são carlos', 'Pata-de-vaca', 'Piolho de cama', 'Pleurodese', 'Poliparasitismo', 'Rato de rabo peludo', 'Sagüi de tufo branco', 'Samambaia das taperas', 'Sarcoma de ewing', 'Transcriptoma', 'Tumor de walker', 'Tunicato', 'Varicela-zoster', 'Agamaglobulinémia', 'Alastrar', 'Anaeróbio', 'Anafiláctico', 'Anatómico', 'Androgénico', 'Angiite', 'Anginoso', 'Angioneurótico', 'Anogenital', 'Anorectal', 'Assistolia', 'Bacilo', 'Bio-disponibilidade', 'Biológico', 'Biossíntese', 'Biotransformação', 'Blister', 'Borborigmo', 'Bronquial', 'Bulbar', 'Buloso', 'Catabolismo', 'Catarata', 'Catarro', 'Cateterismo', 'Ciclo', 'Cicloderma', 'Clónico', 'Colorectal', 'Complexo QRS', 'Condiloma', 'Cronotrópico', 'Crónico', 'Directo', 'Duodeno', 'Ectópico', 'Endotélio', 'Epidérmico', 'Epifisário', 'Erisipela', 'Eritema', 'Espectro', 'Esputo', 'Espécie', 'Estrogénio', 'Exógeno', 'Fenómeno', 'Fungo', 'Galénico', 'Geniturinário', 'Genético', 'Glomerular', 'Glossite', 'Grande mal', 'Herpes zóster', 'Higiénico', 'Hirsutismo', 'Histológico', 'Homogéneo', 'Homólogo', 'Ileite', 'In situ', 'In vivo', 'Intravenoso', 'Jacto', 'Largo espectro', 'Liposoma', 'Livedo', 'Loco-regional', 'Lóquios', 'Mamário', 'Megacolo', 'Megaloblástico', 'Micobactéria', 'Micológico', 'Microrganismo', 'Micótico', 'Miótico', 'Mucopurulento', 'Mutagénico', 'Mutismo', 'Necrose', 'Normotenso', 'Ocitócico', 'Oligoelemento', 'Oncótico', 'Organismo', 'Orgasmo', 'Pacemaker', 'Palpebral', 'Patógeno', 'Percutâneo', 'Peroral', 'Pioderma', 'Piogénico', 'Pirogénico', 'Plasminogénio', 'Polipeptídeo', 'Proptose', 'Protozoário', 'Pénis', 'Quaternário', 'Reagente', 'Refluxo', 'Saprófito', 'Sarcoma', 'Septicémia', 'Sequestro', 'Sigmóide', 'Supino', 'Teratogénico', 'Tinea pedis', 'Tonsilite', 'Torácico', 'Tracoma', 'Transcutâneo', 'Tubo', 'Ulcerogénico', 'Vagal', 'Varicela', 'Vasomotor', 'Vegetativo', 'Viral', 'Vulvar', 'EAS', 'Registro', 'Risco', 'Achatar', 'Cadeia de contág ...
#
# Categoria: Prevenção
# Termos associados: ['Adequació de l’esforç terapèutic', 'Isolamento', 'Assaig d’intervenció comunitària', 'Camussa antibaf', 'Carga antigénica', 'Capuz', 'Taxa de vacinação', 'Cobertura vacunal', 'Comunicat mèdic d’alta', 'Confinamento', 'Cerca sanitária', 'Contenção', 'CVnCoV', 'Desinfetante', 'Distância de segurança', 'Distanciamento de segurança', 'Dose de reforço', 'Efetividade vacinal', 'Eficácia vacinal', 'Eficiência vacinal', 'Vacina Moderna', 'ELISA', 'EPI', 'Equipamento de proteção individual EPI', 'Equip de protecció personal', 'Estudi d’exploració terapèutica', 'Falha vacinal', 'Falha vacinal primária', 'Falha vacinal secundária', 'Gam-COVID-Vac', 'Gel antisèptic', 'Desinfetante das mãos', 'Gel higienitzant', 'Luva', 'Saúde pública', 'Higienização das mãos', 'Hipoestèsia olfactòria', 'Limitació de l’esforç terapèutic', 'Máscara facial', 'Màscara amb filtre de partícules', 'Máscara autofiltrante', 'Màscara FFP', 'Máscara comunitária', 'Màscara mèdica', 'Máscara cirúrgica', 'Mascareta higiènica', 'Mascareta quirúrgica', 'Medida de contenção', 'NVX-CoV2373', 'Viseira', 'Calendário de vacinação', 'Pauta vacunal', 'Període de reacció', 'Persona especialment sensible a la COVID-19', 'Persona vulnerable a la COVID-19', 'Polaina', 'Vacinação primária', 'Proteïna de l’espícula', 'Quarentena', 'Ficar em quarentena', 'Colocado em quarentena', 'RAV', 'Revacinação', 'Salut laboral', 'Servei d’atenció de salut a domicili', 'Test per combinació de mostres', 'Pano antiembaciamento', 'Vacina contra a COVID-19 da Pfizer/ BioNTech', 'Unitat de vigilància intensiva', 'Vacina', 'Vacina COVID-19', 'Vacina Oxford', 'Vacina BBIBP-CorV', 'Vacina Convidecia', 'Vacuna contra la COVID-19', 'Vacina ARNm', 'Vacina Janssen', 'Vacina profilática', 'Vacina Sinovac', 'Vacina de Wuhan', 'Vacina antiviral', 'Imunização', 'Ventilação', 'Visera de protecció', 'Câmara de cintilação híbrida', 'Chá de quebra-pedra', 'Extrato de alho', 'Extrato de camapu', 'Extrato de pariparoba', 'Líquor', 'Microagulha', 'Tula de besouro', '(d)escamação', 'Aplicação', 'Capilar', 'Complicação', 'Espástico', 'Facial', 'Hidratação', 'Maceração', 'Massagem', 'Maxilar', 'Película líquida', 'Perineal', 'Preparação', 'Produto liofilizado', 'Solvente', 'Torsade de pointes', 'Linha de base', 'Produto', 'Proteína da espícula', 'Dgs', 'Laqueação', 'Viscossuplementação', 'Higiene das mãos']
#
# Categoria: Tratamento
# Termos associados: ['Limitação do esforço terapêutico', 'Tratamento da dor', 'Cuidados ao domicílio', 'Cuidados hospitalares', 'Cuidados primários', 'Comissão de bioética', 'Luto', 'Ageísmo', 'Esperança de vida', 'Esperança de vida sem incapacidade', 'Extubação', 'Intubação', 'Justiça distributiva', 'Máscara', 'Monitorização', 'Morte digna', 'Mostra bucofaríngia', 'Mostra rinofaríngia', 'Nebulização', 'Nebulizador', 'Abstenção de tratamento', 'Distanásia', 'Oxigenação', 'Tratamento com oxigénio', 'Princípio da beneficência', 'Princípio da não-maleficência', 'Princípio da precaução', 'Priorização', 'Local de injeção', 'Qualidade de vida QdV', 'Reabilitação respiratória', 'Respiração artificial', 'Ventilador', 'Sedação', 'Seroterapia', 'Suporte vital', 'Tratamento em ambulatório', 'Cânula nasal', 'Unidade de cuidados intensivos', 'Uso compassivo', 'Ventilació mecànica', 'Via de administração', 'Artrodistrator', 'Biochip', 'Bioengenheiro', 'Bipsoro eletrônico', 'Bisturi óptico', 'Chip de DNA', 'Cirurgia a céu aberto', 'Complexo de vanádio', 'Curativo biocompatível', 'Encapsulamento molecular', 'Enxerto orgânico', 'Enzima de reparo', 'Imunossensor amperométrico', 'Microesferas biodegradáveis', 'Nitrato de prata', 'Osseointegração', 'Pinça óptica', 'Prótese de Takimoto', 'Sistema de temporização', 'Técnica sage', 'Terapia fotodinâmica', 'Terapia gênica', 'Tumor de erlich', 'Videodermatoscópio', 'Xenotransplante', 'Arteriografia', 'Bifásico', 'Bio-equivalente', 'Coclear', 'Concreto', 'Cristalização', 'Diátese', 'Electrofisiológico', 'Esterilização', 'Expansor plasmático', 'Extracção', 'Ferropénico', 'Fibrilação', 'Fotossensibilização', 'Físico-químico', 'Implicação', 'Injecção bolus', 'Inorgânico', 'Ionograma', 'Meio de contraste', 'Micronizar', 'Microspório', 'Mineralização', 'Modulador', 'Neoplástico', 'Oculogiro', 'Ortopédico', 'Prótese', 'Pulverizador', 'Químio-receptor', 'Radioactividade', 'Receptor', 'Supositório', 'Terapia', 'Veículo', 'Virilização', 'Óptico', 'Óvulo', 'Catálogo de intervenções', 'COVID-19 e Sars-cov-2', 'Bloco operatório', 'Desfibrilhador', 'Eco-doppler', 'Encefálico', 'Enteroscópio', 'Fibroscópio', 'Flebotomia', 'Microclister', 'Oxigenoterapia', 'Termocoagulação', 'Videonistagmograma']
#
# Categoria: Clínica
# Termos associados: ['Ageusia', 'Anosmia', 'Ansiedade de antecipação', 'Arritmia', 'Assintomático', 'Astenia', 'Auto-inflamação', 'Brônquio', 'Bronquíolo', 'Bronquiolite', 'Cànula nasal', 'Cefalàlgia', 'Cefaleia', 'Quadro clínico', 'Coagulopatia', 'Col·lapse cardiocirculatori', 'Comorbilidade', 'Congestão nasal', 'Conjuntivite', 'Contágio', 'Contágio imediato', 'Contágio indireto', 'Contagiosidade', 'COVID-19', 'COVID-19 persistente', 'Diarreia', 'Disfonia', 'Displàsia alveolar congènita', 'Falta de ar', 'Dor no peito', 'Eczema', 'Embolia pulmonar longembolie', 'Exsudado', 'Falta de concentração', 'Exaustão', 'Exaustão mental', 'Fadiga pandêmica', 'Febre', 'Febrícula', 'Fibrose', 'Grave', 'Hepatotoxicidade', 'Hipoestèsia gustativa', 'Hipoestesia gustativa', 'Hipoestesia olfativa', 'Hipòsmia', 'Hipoxemia', 'Hipoxia', 'Infeção', 'Infeção associada aos cuidados de saúde', 'Infecció nosocomial', 'Infeção por gotículas', 'Infeciologia', 'Infiltrado', 'Insónia', 'Limfocitopènia', 'Mal de cap', 'Mal de costat', 'Mal de pit', 'Tonturas', 'Mialgia', 'Náuseas', 'Frieira', 'Pneumonia', 'Pródromo', 'Pulmonia', 'Reação sistémica', 'Reação local', 'Reacció sistèmica', 'Recaída', 'Recidiva', 'Recrudescência', 'Reinfeção', 'Semiologia', 'Sepsia', 'Sequela', 'Sinal', 'Sintoma', 'Sincropèxia', 'Síndrome del destret respiratori agut', 'Síndrome de dificuldade respiratória aguda', 'Síndrome de dificuldade respiratória neonatal', 'Síndrome post COVID-19', 'Síndrome respiratória aguda grave SARS', 'Síndrome respiratória do Médio Oriente MERS', 'Taquisistolia', 'Temps de convalescència', 'Tosse', 'Tosse produtiva', 'Tosse seca', 'Traqueotomia', 'Trombo', 'Trombose', 'Urticária', 'Emese', 'Colapso circulatório', 'Acidente vascular cerebral isquêmico', 'Acidose metilmalônica', 'Alergia asmática', 'Amiloidose sistêmica senil', 'Angina instável', 'Apoptose', 'Atrofia espinhal progressiva tardia', 'Broncoconstrição', 'Broncodilatação', 'Bulimia nervosa', 'Câncer de boca', 'Câncer de colo de útero', 'Câncer de estômago', 'Câncer de mama', 'Câncer de pele', 'Câncer de próstata', 'Câncer de pulmão', 'Câncer de tireóide', 'Câncer gástrico', 'Choque hemorrágico', 'Coagulação intravascular disseminada', 'Coagulopatia de consumo', 'Colite hemorrágica', 'Craniossinostose', 'Crise de pânico', 'Crise hipoglicêmica', 'Cromoblastomicose', 'Degeneração macular relacionada à idade', 'Depressão alastrante de leão', 'Derrame pleural', 'Diarréia do viajante', 'Distrofia muscular progressiva', 'Distúrbio do sono', 'Doença da vaca louca', 'Doença isquêmica do coração', 'Doença reemergente', 'Droga neuroativa', 'Encefalopatia espongiforme felina', 'Encefalopatia espongiforme bovina', 'Encefalopatia espongiforme', 'Epilepsia de lobo temporal mesial', 'Epilepsia pós-traumática', 'Esclerose lateral amiotrófica', 'Esclerose múltipla', 'Esclerose sistêmica', 'Estímulo aversivo', 'Estresse oxidativo', 'Falcoemulsificação', 'Febre maculosa', 'Fototrombose mediada pela indocianina verde', 'Hiperbilirrubinemia', 'Hiperplasia epitelial', 'Homocistinúria', 'Icterícia fisiológica', 'Ilhota pancreática', 'Infarto medular', 'Infecção perinatal', 'Insuficiência cardíaca crônica', 'Insuficiência cardíaca grave', 'Insuficiência renal aguda', 'Isquemia cerebral', 'Leucemia mielóide aguda', 'Leucemia mielóide crônica', 'Lúpus eritematoso sistêmico', 'Mal de alzheimer', 'Mal de chagas', 'Mal de lutz', 'Metaplasia intestinal', 'Miastenia grave', 'Mucosite oral', 'Pele artificial', 'Pneumonia asiática', 'Porfíria aguda intermitente', 'Ptose palpebral', 'Reabsorção dentária', 'Síndrome da fadiga crônica', 'Síndrome da rubéola congênita', 'Síndrome de turner', 'Síndrome do desconforto respiratório', 'Síndrome respiratória aguda severa', 'Síndrome hemolítica urêmica', 'Transtorno cognitivo', 'Transtorno do pânico', 'Transtorno obsessivo compulsivo', 'Petit mal; epilepsia menor', 'Acrocianose', 'Agranulocitose', 'Alcoolismo', 'Alergia', 'Alopecia', 'Alveolite', 'Alérgico', 'Ambliopia', 'Amenorreia',  ...
#
# Categoria: Epidemiologia
# Termos associados: ['Agrupamento', 'Achatar a curva', 'Bolha alargada', 'Bolha bolha social', 'Bronquitis capil·lar', 'Surto epidemiológico', 'Cadeia epidemiológica', 'Caso', 'Caso confirmado', 'Caso descartado', 'Doente zero', 'Caso possível', 'População vulnerável em risco', 'Contacto', 'Contacto próximo', 'Controlo', 'Curva de contágio', 'Coronavirus de la COVID-19', 'Coronavirus de la MERS', 'Coronavirus de la SARS', 'Desconfinamento', 'Levantamento do desconfinamento', 'Emergência de saúde pública', 'Endemia', 'Epidemia', 'Epidemiologia', 'Erradicação', 'Sazonalidade', 'Mortalidade excessiva', 'Exsudat bucofaringi', 'Fator de risco', 'Fase de contenção', 'Fase de mitigação', 'Fómite', 'Grupo bolha', 'Grupo de risco', 'Imunidade comunitária', 'Incidência', 'Incidência acumulada IA', 'Incubação', 'Latência', 'Memória imunológica', 'Mortalidade', 'Vaga', 'Organização Mundial de Saúde', 'Pandemia', 'Certificado COVID', 'Fase de incubação', 'Período de infeção', 'Pico de contágio', 'População-alvo', 'População sentinela', 'Prevalência', 'Rastreio de contactos', 'Rastreador | rastreadora', 'Nova vaga epidémica', 'Serviço nacional de saúde', 'Seroprevalência', 'Sindemia', 'Supercontagiador', 'Suscetível', 'Taxa de contágio', 'Taxa de letalidade', 'Taxa de mortalidade', 'Rastreabilidade', 'Transmissível', 'Transmissão comunitária', 'Transmissão horizontal', 'Transmissão vertical', 'Vacuna antivírica', 'Número básico de reprodução', 'Número efetivo de reprodução', 'Velocitat reproductiva empírica', 'Virus de la COVID-19', 'Bactéria entero-hemorrágica', 'Choque séptico', 'Febre do oeste do nilo', 'Glucoíris', 'Hantavirose', 'Insulina transgênica', 'Leishmaniose cutâneo-mucosa', 'Leishmaniose tegumentar americana', 'Linfoma de burkitt', 'Mal de creutzfeldt-jacob', 'Metapneumovírus', 'Mimivírus', 'Papiloma vírus', 'Tripanossomíase americana', 'Vírus amarílico', 'Vírus cantagalo', 'Vírus respiratório sincicial', '(herpes) zóster', 'Agalactia', 'Bacteriológico', 'Bacteróide', 'Candidíase', 'Ceratoconjuntivite', 'Cistite', 'Colecistite', 'Dermatite', 'Epidemiológico', 'Epitelioma', 'Espondilite', 'Faringite', 'Furunculose', 'Gengivite', 'Hepatite', 'Hepatobiliar', 'Hepatotóxico', 'Herpes simplex', 'Infecção', 'Influenza', 'Iridociclite', 'Linfoma', 'Meningite', 'Micose', 'Mucociliar', 'Otite', 'Paniculite', 'Papiloedema', 'Pielonefrite', 'Pitiríase', 'Psoríase', 'Tinitus (aurium)', 'Varíola bovina', 'Vulvovaginite', 'Cifose', 'Saciforme']
#
# Categoria: Contexto social
# Termos associados: ['Alta n f; alta hospitalar n f; alta médica n f', 'Autoridade de saúde', 'Convalescença', 'Delegado de segurança | delegada de segurança', 'Incapacidade', 'Estado de alerta', 'Apoio extraordinário à manutenção de contrato de trabalho', 'Incapacitação permanente', 'Incapacidade temporária IT', 'Infodemia', 'Medicalizar', 'Avaliação do dano corporal', 'Novo normal', 'Perícia médico-legal', 'Pessoa com maior risco de contrair COVID-19', 'Plano de contingência para a COVID-19', 'Medicina do trabalho', 'Uso de locais ou espaços públicos para fins sanitários', 'Serviço de prevenção', 'Socialização', 'Telemedicina', 'Teletrabalho', 'Tempo de recuperação', 'Recolher obrigatório']
#
# Categoria: Componentes e conceitos farmacológicos
# Termos associados: ['Antiviral', 'Compte hemàtic', 'Rapamicina', 'Ação vasoconstritora', 'Ácido acetilsalicílico', 'Ácido caínico', 'Ácido gama-aminobutírico', 'Alfa-tocoferol', 'Beta-amilóide', 'Beta-bloqueador', 'Efeito placebo', 'Endotelina', 'Eritropoetina', 'Hemopressina', 'Hidrocarboneto policíclico aromático', 'Hormônio regulador', 'Microarray', 'Pró-insulina', 'Simocaína', 'Soro hiperimune', 'Terapia de reposição hormonal', 'Transtirretina', 'Adrenolítico', 'Adrenérgico', 'Adstringente', 'Albumina', 'Alcalóide', 'Alérgeno', 'Analgésico', 'Analéptico', 'Anti-helmíntico', 'Anti-hipertensivo', 'Anti-histamina', 'Anti-infeccioso', 'Anti-inflamatório', 'Anti-séptico', 'Antialérgico', 'Antiarrítmico', 'Antiasmático', 'Antibacteriano', 'Antibiograma', 'Antibioterapia', 'Anticoagulante', 'Anticolinérgico', 'Anticonvulsivante', 'Antidepressivo', 'Antidiabético', 'Antidiurético', 'Antidopaminérgico', 'Antiemético', 'Antiepiléptico', 'Antiestrogénico', 'Antiexudativo', 'Antifibrinolítico', 'Antifúngico', 'Antimicrobiano', 'Antimicótico', 'Antimitótico', 'Antineoplástico', 'Antioxidante', 'Antiproliferativo', 'Antipruriginoso', 'Antipsicótico', 'Antispasmódico', 'Antitoxina', 'Antitrombótico', 'Antiácido', 'Antídoto', 'Antígeno', 'Atóxico', 'Bactericida', 'Bacteriostático', 'Betamimético', 'Bioquímico', 'Carcinogénico', 'Cardiogénico', 'Cardiotóxico', 'Ceratolítico', 'Cerebrovascular', 'Cinético', 'Citotóxico', 'Colesterol', 'Contra-indicação', 'Contraceptivo', 'Corticosteróide', 'Cosmético', 'Cromossómico', 'Degenerativo', 'Desinfectante', 'Diurético', 'Efeito colateral', 'Endotóxico', 'Endógeno', 'Esporádico', 'Esquelético', 'Estimulante', 'Extrapiramidal', 'Extravascular', 'Farmacêutico', 'Fetotóxico', 'Fibrinolítico', 'Fármaco', 'Glicósido', 'Glumerolonefrite', 'Glúten', 'Hermético', 'Hidrófilo', 'Hipotenso', 'Hormonal', 'Imunossupressor', 'Inotrópico', 'Invasivo', 'Lipoproteína', 'Luético', 'Lítico', 'Medicamento', 'Medicação', 'Medicinal', 'Mielotóxico', 'Morfinomimético', 'Mucolítico', 'Narcótico', 'Nefrotóxico', 'Neurotóxico', 'Neurovegetativo', 'Nutriente', 'Osmótico', 'Ototóxico', 'Paliativo', 'Paravenoso', 'Profilaxia', 'Progestogeno', 'Protectivo', 'Proteolítico', 'Proteína', 'Protrombina', 'Psicoléptico', 'Psicológico', 'Psicomotor', 'Psicossomático', 'Psicotrópico', 'Psiquiátrico', 'Psíquico', 'Quimioterápico', 'Químico', 'Relaxante', 'Renovascular', 'Semi-sintético', 'Simpaticomimético', 'Soro', 'Suplemento', 'Terapêutico', 'Toxicológico', 'Transaminase', 'Trombolítico', 'Tóxico', 'Uricossúrico', 'Vasoactivo', 'Vasopressor', 'Isolamento profilático', 'Corticoesteroide', 'Endovenoso', 'Mesoterapia', 'Soroterapia', 'Anticorpos']
#
# Categoria: Diagnóstico
# Termos associados: ['Assaig clínic aleatoritzat', 'Auto-amostragem', 'Carga viral', 'Cassete', 'Rastreio', 'Cultura', 'Deteção precoce', 'Diagnosi', 'Diagnóstico', 'D-dímero', 'Iniciador', 'Ensaio de imunoadsorção enzimática ELISA', 'Zaragatoa', 'Estudi de confirmació terapèutica', 'Estudi de farmacologia humana', 'Estudi de microdosi', 'Falso negativo', 'Falso positivo', 'Ferritina', 'Fibrinogénio', 'Esfregaço', 'Contagem sanguínea', 'História clínica', 'Imunocromatografia', 'Imunoglobulina', 'Imunoglobulina G', 'Imunoglobulina M', 'Inteligência artificial IA', 'Desidrogenase láctica', 'Linfocitopenia', 'Marcador inflamatório', 'Exsudado nasofaríngeo', 'Exsudado orofaríngeo', 'Proteína C-reativa', 'Prova antigènica', 'Teste de antigénio', 'Teste combinado', 'Prova diagnòstica amb ELISA', 'Teste de diagnóstico por PCR', 'Prova diagnòstica ràpida', 'Teste de diagnóstico rápido', 'Teste serológico', 'Radiografia', 'Radiómica', 'Reação em cadeia da polimerase PCR RCP', 'Serologia', 'Sonda', 'Sonda molecular', 'Tempo de Quick', 'Análise de anticorpos', 'Testagem em massa', 'Título de anticorpos', 'Triagem', 'Análise biomecânica', 'Angiografia de retina', 'Baciloscopia', 'Biologia reprodutiva', 'Biologia sistêmica', 'Bioprótese', 'Biópsia óptica', 'Capsulotomia anterior estereotáxica por gamma-knife', 'Carcinogênese química', 'Ceratoscopia', 'Cingulotomia anterior', 'Cirurgia fetal a céu aberto', 'Clonagem reprodutiva', 'Clonagem terapêutica', 'Cristalografia de proteínas', 'Dermatoscopia', 'Ensaio clínico duplo-cego', 'Enzima conversora da angiotensina I', 'Epidemiologia matemática', 'Espectrometria de massa', 'Espectroscopia de fluorescência', 'Espectroscopia de ressonância nuclear magnética', 'Genética molecular', 'Glicosímetro', 'Hemopure', 'Medicina comportamental', 'Microscopia eletrônica de varredura', 'Neuromorfometria', 'Odontogeriatria', 'Radiocirurgia', 'Ressonância magnética funcional', 'Teste de carga viral', 'Teste de exercício cardiorrespiratório', 'Topógrafo intracirúrgico', 'Vacina autóloga', 'Vacina de DNA', 'Vacina quádrupla', 'Videomicroscopia', 'Anestesia', 'Biodegração', 'Biopsia', 'Carboidrato', 'Cardiológico', 'Cardiovascular', 'Cirúrgico', 'Cistoscopia', 'Citocrómio', 'Clínico', 'Creatinemia', 'Dermatofitia', 'Dermatológico', 'Dermografia', 'Detecção', 'Disenteria', 'Documento', 'Dosagem', 'Dose-padrão', 'Ecografia', 'Electrocardiografia', 'Electroencefalografia', 'Endoscopia', 'Epigástrico', 'Episiotomia', 'Esfoliação', 'Espasmolítico', 'Espermatogénese', 'Estomatológico', 'Etiologia', 'Farmacocinética', 'Farmacodinâmica', 'Farmacológico', 'Fermentação', 'Filtração', 'Fisiológico', 'Geriátrico', 'Ginecológico', 'Glicose', 'Gonioscopia', 'Hematológico', 'Hemodiálise', 'Hemoperfusão', 'Hemostasia', 'Histerectomia', 'Identificação', 'In vitro', 'Indicação', 'Local', 'Microbiológico', 'Micrografia', 'Microscópico', 'Microvilosidade', 'Monoterapia', 'Médico', 'Neonatal', 'Obstetrício', 'Oclusão', 'Oftalmológico', 'Ooforectomia', 'Osteotomia', 'Otorrinolaringologia', 'Ovulação', 'Parassimpaticomimétrico', 'Patológico', 'Pediátrico', 'Peritonite', 'Politerapia', 'Posologia', 'Prognose', 'Pré-clínico', 'Pré-medicação', 'Pré-natal', 'Pré-operatório', 'Pós-natal', 'Pós-operativo', 'Pós-parto', 'Quimioterapia', 'Radiológico', 'Radioterapia', 'Reconvalescença', 'Teratológico', 'Testicular', 'Transfusão', 'Transitório', 'Transplantação', 'Urografia', 'Vacinação', 'Vasodilatação', 'Xeroftalmia', 'Xerostomia', 'Medida-síntese', 'Processo', 'Público sujeito', 'Adenoidectomia', 'Amigdalectomia', 'Angiografia', 'Angioplastia', 'Aponevrectomia', 'Artrocentese', 'Artroplastia', 'Artroscopia', 'Audiograma', 'Biópsia', 'Broncoscopia', 'Capilaroscopia', 'Citologia', 'Citometria', 'Citopatologia', 'Citoquímica', 'Colonoscopia', 'Colostomia', 'Corticectomia', 'Cricotirotomia', 'Dacriocistorrinostomia', 'Dieta cetogénica', 'Discectomia', 'Diverticulectomia', 'Ecocardiograma', 'Eletrocardiograma', 'Eletroencefalograma', 'Eletrofisio ...
#
# Categoria: Anatomia
# Termos associados: ['Esgotament mental', 'Gotícula respiratòria', 'Cavidade pleural', 'Célula multipotencial', 'Córtex cingulado', 'Disfunção velofaríngea', 'Enxerto periférico heterólogo', 'Enzima cicloxigenase', 'Enzima degradadora de insulina', 'Fator de estimulação de colônia de granulócito', 'Fator de crescimento de fibroblastos', 'Fibrilação ventricular', 'Genoma mitocondrial', 'Hemoderivado', 'Hormônio de crescimento', 'Hormônio de crescimento biossintético', 'Lesão medular', 'Líquido cefalorraquidiano', 'Microflora intestinal', 'Mielomeningocele', 'Neurônio biônico', 'Núcleo mediano da rafe', 'Núcleo paraventricular', 'Rede neural artificial', 'Secreção de prolactina', 'Sistema endócrino', 'Sistema límbico', 'Sistema nervoso parassimpático', 'Sistema nervoso periférico', 'Terminal nervoso simpático', 'Abdómen', 'Arterial', 'Arteriolar', 'Artério-venoso', 'Atrioventricular', 'Auricular', 'Bilateral', 'Bucofaríngeo', 'Cardiomegália', 'Cardiopulmonar', 'Cardiorespiratório', 'Cardiosselectivo', 'Cardiotónico', 'Cardíaco', 'Cerebral', 'Cervical', 'Coagulação', 'Cognitivo', 'Colinérgico', 'Colo do útero', 'Cor pulmonar', 'Corpo lúteo', 'Craniano', 'Cutâneo', 'Córnea', 'Córtice', 'Digestivo', 'Endócrino', 'Entero-hepático', 'Epidural', 'Epitélio', 'Esfíncter', 'Esteróide', 'Extra-renal', 'Exócrino', 'Fezes', 'Fungistático', 'Gastrintestinal', 'Gastro-esofágico', 'Gastroduodenal', 'Genital', 'Hepatocelular', 'Hepático', 'Integumentário', 'Intervertebral', 'Intestinal', 'Intramuscular', 'Intraocular', 'Intravascular', 'Lenticular', 'Leucócito', 'Linfocítico', 'Lombar', 'Maculopapular', 'Mastócito', 'Membrana', 'Membrana celular', 'Mental', 'Metabolismo', 'Microcirculação', 'Microssómico', 'Mineralocorticóide', 'Miorrelaxante', 'Molecular', 'Mucocutâneo', 'Mucosa', 'Muscular', 'Musculatura', 'Nasal', 'Nasolacrimal', 'Neuroléptico', 'Neurológico', 'Neuromuscular', 'Neuronal', 'Neurotransmissor', 'Neurótico', 'Neutrófilo', 'Nosocomial', 'Ocular', 'Oculomucocutâneo', 'Orofacial', 'Ortostático', 'Osteodistrofia', 'Papilar', 'Parenteral', 'Parênquima', 'Perinatal', 'Periorbital', 'Perivascular', 'Placa dentária', 'Postural', 'Prepúcio', 'Pulmonar', 'Pulsação', 'Pélvico', 'Quelóide', 'Respiratório', 'Retroesternal', 'Reumatóide', 'Sensorial', 'Sináptico', 'Subaracnóide', 'Supraventricular', 'Tracto (gastrintestinal)', 'Trófico', 'Tubercular', 'Tuberculostático', 'Umeroscapular', 'Urinário', 'Urogenital', 'Vascular', 'Ventricular', 'Vertebral', 'Visceral', 'Válvula', 'Útero', 'Cefalorraquidiano', 'Densitometria óssea', 'Eritrócito', 'Hipófise', 'Melanócito', 'Meningocelo', 'Mielograma', 'Neurinoma', 'Neuroma', 'Neuromodulação', 'Osteossíntese', 'Ressincronização cardíaca', 'Sacroilíaco', 'Tireoglosso']
#
# Categoria: Monitoramento e avaliação
# Termos associados: ['Fase IV', 'Prova PCR', 'Bio feedback', 'Análise', 'Avaliação', 'Catálise', 'Diálise', 'Ensaio', 'Fase', 'Indicativo', 'Induração', 'Invalidar', 'Investigação', 'Prova', 'Reavaliação', 'Acompanhamento', 'Análise baseada em evidências', 'Análise de Impacto Regulatório', 'Análise de indicadores', 'Análise de risco', 'Análise de viabilidade', 'Análise estratégica', 'Análise prospectiva', 'Análise situacional', 'Auditoria', 'Avaliação de desempenho individual e institucional', 'Avaliação de impacto', 'Avaliação de processo', 'Avaliação de resultados', 'Cultura de monitoramento e avaliação', 'Elaboração de indicadores', 'Evidências para tomada de decisão', 'Ficha de descrição da intervenção', 'Indicador de desempenho', 'Indicador de economicidade', 'Indicador de efetividade', 'Indicador de eficácia', 'Indicador de excelência', 'Indicador de gestão', 'Indicador de progresso', 'Indicador social', 'Institucionalização do monitoramento e avaliação', 'Instrumentos de gestão', 'Matriz de indicadores', 'Metodologia de avaliação', 'Modelo de avaliação', 'Monitoramento', 'Pesquisa avaliativa', 'Resultados intermediários', 'Tomada de decisão', 'Exame']
#
# Categoria: Gestão de dados e informação
# Termos associados: ['IP', 'Bioinformática', 'Apresentação', 'Digitalização', 'Hipótese', 'Implantação', 'Produção', 'Referência', 'Resposta', 'Solução', 'Tomografia', 'Agregação de dados', 'Análise de dados', 'Banco de dados', 'Base de dados', 'Base legal', 'Base populacional', 'Ciência da informação', 'Ciência de dados', 'Coleta de dados', 'Confiabilidade', 'Conjunto de dados', 'Conjunto mínimo de dados', 'Dados abertos', 'Disseminação da informação', 'Documentação da informação', 'Fonte', 'Fontes de dados', 'Fontes de informação', 'Índice', 'Memória de cálculo', 'Metadados', 'Produção de conhecimento', 'Qualidade da informação', 'Segurança da informação', 'Visualização de dados', 'Ensino a distância', 'Referenciação']
#
# Categoria: Políticas e intervenções na saúde pública
# Termos associados: ['OMS', 'Medicina à distância', 'Hospitalização', 'Prevenção', 'Primeira vacinação', 'Urgência', 'Ações de saúde', 'Ações intersetoriais', 'Análise de situação em saúde', 'Avaliação em saúde', 'Estabelecimento Assistencial de Saúde', 'Gestor de informação em saúde', 'Indicador de saúde', 'Informação em saúde', 'Interoperabilidade da informação em saúde', 'Planejamento em saúde', 'Política pública de saúde', 'Sala de situação de saúde', 'Serviços de saúde', 'Sistemas de informação em saúde', 'Sistemática de monitoramento e avaliação em saúde', 'Valor em saúde', 'Valor público em saúde', 'Estado de emergência', 'Ambulatório', 'Centro hospitalar', 'Cuidados paliativos', 'Terapêutica', 'Taxa de letalidade de uma doença']
#
# Categoria: Metodologias e ferramentas
# Termos associados: ['Prova immunològica', 'Test PCR', 'Test ràpid', 'Técnica de sorting', 'Critério', 'Cálculo', 'Diâmetro', 'Estatístico', 'Fundamental', 'Instrução', 'Micrograma', 'Minimizar', 'Numular', 'Partícula', 'Parâmetro', 'Procedimento', 'Qualitativo', 'Quantitativo', 'Vestibular', 'Aprendizado de máquina', 'Benchmarking', 'Big data', 'Brainstorming', 'Cálculo do indicador', 'Custo-benefício', 'Custo-efetividade', 'Dados qualitativos', 'Dados quantitativos', 'Dashboard', 'Datalake', 'Ficha de qualificação do indicador', 'Fórmula de cálculo', 'Grau de implantação', 'Indicador', 'Indicador analítico', 'Indicador complexo', 'Indicador de eficiência', 'Indicador de esforço', 'Indicador de execução', 'Indicador de impacto', 'Indicador de infraestrutura', 'Indicador de insumo', 'Indicador de processo', 'Indicador de produto', 'Indicador de resultado', 'Indicador simples', 'Indicador sintético', 'Índice de referência', 'Interpretação do indicador', 'Limitação do indicador', 'Machine learning', 'Mensuração', 'Método', 'Metodologia', 'Modelo lógico', 'Unidade de medida', 'Uso do indicador', 'Curva exponencial', 'Raios x', 'Screening', 'Tilt test', 'Unicard', 'Taxa de mortalidade específica por uma causa']
#
# Categoria: Governança e administração pública
# Termos associados: ['Falsa operação', 'Anergia', 'Anexite', 'Associação', 'Bursite', 'Condição', 'Condução', 'Congestão', 'Conselho', 'Constitucional', 'Coordenação', 'Discrasia', 'Distribuição', 'Ergotismo', 'Estado', 'Estado de equilíbrio', 'Extensão', 'Externo', 'Focalização', 'Habitual', 'Imobilização', 'Incisão', 'Inibição', 'Integridade', 'Interferência', 'Interno', 'Localização', 'Mediador', 'Mediar', 'Mobilização', 'Observação', 'Oportunista', 'Orientação', 'Periódico', 'Pico do débito', 'Privação', 'Regional', 'Região', 'Regulação', 'Secreção', 'Sedimentação', 'Supervisão', 'Trânsito', 'Tópico', 'Unilateral', 'Vigilância', 'Voluntário', 'Accountability', 'Acesso à informação', 'Agenda estratégica', 'Agenda política', 'Alocação de recursos', 'Articulação', 'Atividades', 'Base geográfica', 'Boas práticas', 'Business Intelligence', 'Colegiado', 'Comitê consultivo', 'Compliance', 'Controle', 'Controle social', 'Desempenho institucional', 'Destinação de recursos', 'Entidades vinculadas', 'Execução da política', 'Gestão da informação', 'Gestão do conhecimento', 'Gestão tripartite', 'Governabilidade', 'Governança pública', 'Governo aberto', 'Informação', 'Informação estratégica', 'Intercâmbio de informação', 'Meta', 'Normativa', 'Órgãos colegiados', 'Pacto', 'Pactuação', 'Painel de informação', 'Painel de monitoramento', 'Partes interessadas', 'Política', 'Política implementada', 'Política pública', 'Política social', 'Processo decisório', 'Rede', 'Responsável pelo monitoramento', 'Stakeholders', 'Território', 'Transparência', 'Unidades', 'Decreto presidencial', 'Moratória', 'Admissão', 'Centros de referência', 'Mapa 24 horas', 'Taxas moderadoras', 'Dever cívico de recolhimento domiciliário', 'Transmissão na comunidade', 'Transmissão indireta']
#
# Categoria: Planeamento e estratégia
# Termos associados: ['Análogo', 'Base', 'Concepção', 'Factor de risco', 'Objectivo', 'Percepção', 'Pós-carga', 'Subjectivo', 'Teórico', 'Título', 'Visão', 'Análise ex-ante', 'Análise ex-post', 'Área finalística', 'Cadeia de valor', 'Cenário', 'Ciclo de políticas públicas', 'Competências organizacionais', 'Diretrizes', 'Escopo', 'Esferas de gestão', 'Estratégia', 'Forma de implementação', 'Formulação de políticas', 'Gestão de risco', 'Gestão estratégica', 'Implementação', 'Implementação da política', 'Marco lógico', 'Matriz de informação estratégica', 'Matriz lógica', 'Modelo de gestão', 'Objetivo', 'Objetivos estratégicos', 'Orçamento', 'Planejamento', 'Planejamento estratégico', 'Planejamento governamental', 'Plano', 'Programa', 'Projeto', 'Público-alvo', 'Público estratégico', 'Referencial estratégico', 'Valor público', 'Protético']

# %%
#versão para inserir a categoria nos dicionários dos termos mesmo como entrada

with open("dicionario_final_similares.json", encoding="utf-8") as f:
    termos = json.load(f)

resultado = {}

for termo, dados in termos.items():
    # Se já tem categoria, traduz 
    if "Categoria" in dados:
        cat_catalan = dados["Categoria"]
        cat_pt = categorias_traduzidas.get(cat_catalan, cat_catalan)
        dados["Categoria"] = cat_pt
    else:
        termo_emb = get_embedding(termo)
        sims = {cat: cosine_similarity([termo_emb], [emb])[0, 0]
                for cat, emb in categoria_embeddings.items()}
        cat_pt = max(sims, key=sims.get)
        dados["Categoria"] = cat_pt
    resultado[termo] = dados

with open("dicionario_categorizado_v2.json", "w", encoding="utf-8") as f:
    json.dump(resultado, f, ensure_ascii=False, indent=2)

print("Classificação concluída! Resultado dicionario_categorizado_v2.json")
# Out:
# Classificação concluída! Resultado dicionario_categorizado_v2.json
